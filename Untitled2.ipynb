# %% [markdown]
# <a href="https://colab.research.google.com/github/rose7dh/training-program/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("Enter list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements in the list"))
  list.append(b)
print("LIST:",list)
# Out:
# Enter list size: 4
# Enter the elements in the list12
# Enter the elements in the list34
# Enter the elements in the list12
# Enter the elements in the list10
# LIST: [12, 34, 12, 10]

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
largest=list[0]
for i in range(1,a):
  if(list[i]>largest):
    largest=list[i]
print("Largest element=",largest)
# Out:
# Enter the list size:3
# enter the elements:12
# enter the elements:10
# enter the elements:23
# Largest element= 23

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
smallest=list[0]
for i in range(1,a):
  if(list[i]<smallest):
    smallest=list[i]
print("Smallest element=",smallest)
# Out:
# Enter the list size:4
# enter the elements:16
# enter the elements:20
# enter the elements:2
# enter the elements:1
# S1mallest element= 1

# %%
a=int(input("Enter the number of elements:"))
list=[]
sum=0
for i in range(a):
  b=int(input("Enter the elements:"))
  list.append(b)
  sum=sum+b
print("LIST:",list)
print("Sum of numbers=",sum)
# Out:
# Enter the number of elements:3
# Enter the elements:13
# Enter the elements:11
# Enter the elements:90
# LIST: [13, 11, 90]
# Sum of numbers= 114

# %%
a=int(input("Enter an array size:"))
arr=[]
for i in range(a):
  el=int(input("Enter array elements:"))
  arr.append(el)
print("Reversed array is:",arr[::-1])
# Out:
# Enter an array size:4
# Enter array elements:13
# Enter array elements:11
# Enter array elements:90
# Enter array elements:34
# Reversed array is: [34, 90, 11, 13]

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
k=int(input("Enter an element to be searched:"))
if k in list:
    print("Element exist!")
else:
    print("Element not exist!")
# Out:
# Enter the list size:4
# enter the elements:11
# enter the elements:22
# enter the elements:33
# enter the elements:44
# Enter an element to be searched:55
# Element not exist!

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
el=int(input("enter the element to be checked"))
count=list.count(el)
print("occurance of ",el,"is:",count)
# Out:
# Enter the list size:4
# enter the elements:12
# enter the elements:11
# enter the elements:23
# enter the elements:45
# enter the element to be checked12
# occurance of  12 is: 1

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
list.sort()
print("Second largest element is:",list[-2])
# Out:
# Enter the list size:3
# enter the elements:23
# enter the elements:22
# enter the elements:12
# Second largest element is: 22

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
list.sort()
print("Sorted array is:",list)
# Out:
# Enter the list size:3
# enter the elements:122
# enter the elements:12
# enter the elements:1
# Sorted array is: [1, 12, 122]

# %%
n=int(input("Enter the no. of elements: "))
a=[]
for i in range(n):
  a.append(int(input("Enter the element: ")))
print("List=",a)
n=[]
for i in a:
  if i not in n:
    n.append(i)
print("Updated list=",n)
# Out:
# Enter the no. of elements: 3
# Enter the element: 12
# Enter the element: 11
# Enter the element: 10
# List= [12, 11, 10]
# Updated list= [12, 11, 10]

# %%
i=map(int,(input("Enter elements:").split()))
print(list(i))
# Out:
# Enter elements:10 2 34 12
# [10, 2, 34, 12]

# %%
arr =[10,20,30,40,50]
print(arr[1:4])
print(arr[:3])
print(arr[2:])
print(arr[::-1])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50]
# [50, 40, 30, 20, 10]

# %%
r=int(input("Enter number of rats: "))
unit=int(input("Enter food consumed by each rat: "))
n=int(input("Enter number of houses: "))
arr=list(map(int, input("Enter food in each house: ").split()))

if arr is None:
    print(-1)
else:
    fn= r*unit
    food = 0
    houses = 0
    for i in range(n):
        food = food + arr[i]
        houses = houses + 1

        if food >= fn:
            break

    if food < fn:
        print(0)
    else:
        print(houses)
# Out:
# Enter number of rats: 7
# Enter food consumed by each rat: 2
# Enter number of houses: 8
# Enter food in each house: 2 8 3 5 7 4 1 2
# 4

# %%
a=int(input("Enter your number:"))
rev=0
while a>0:
  num=a%10
  rev=rev*10+num
  a=a//10
print("Reversed number is:",rev)
# Out:
# Enter your number:56732
# Reversed number is: 23765

# %%
a=input("Enter your string:")
rev=""
for char in a:
  rev=char +rev
print("Reversed string is:",rev)
# Out:
# Enter your string:adithya
# Reversed string is: ayhtida

# %%
a=int(input("Enter your number:"))
sum=0
while a>0:
  num=a%10
  sum=sum+num
  a=a//10
print("Sum of digits is:",sum)
# Out:
# Enter your number:345
# Sum of digits is: 12

# %%
a=int(input("Enter your number:"))
largest=0
while a>0:
  num=a%10
  if num>largest:
    largest=num
  a=a//10
print("Largest digit is:",largest)
# Out:
# Enter your number:25914
# Largest digit is: 9

# %%
a=input("Enter your string:")
if a==a[::-1]:
  print("string is palindrom!")
else:
  print("String is not palindrom!")
# Out:
# Enter your string:jeni
# String is not palindrom!

# %%
a=int(input("Enter your number:"))
digit=a
rev=0
while a>0:
  num=a%10
  rev=rev*10+num
  a=a//10
if rev==digit:
  print("Number is palindrom!")
else:
  print("Number is not palindrom!")
# Out:
# Enter your number:5671
# Number is not palindrom!

# %%
print("CHARACTER COUNT WITHOUT BUILT IN")
a=input("Enter your string:")
count=0
for char in a:
  count=count+1
print("Count of characters is:",count)

print("CHARACTER COUNT WITH BUIT IN")
string=input("Enter your string:")
for char in string:
  length=len(string)
print("count of characters is:",length)
# Out:
# CHARACTER COUNT WITHOUT BUILT IN
# Enter your string:adithya
# Count of characters is: 7
# CHARACTER COUNT WITH BUIT IN
# Enter your string:jeni
# count of characters is: 4

# %%
a=input("Enter your string:")
vow=0
cons=0
for char in a:
  if char=='a' or char=='i' or char=='o' or char=='e' or char=='u' or char=='A' or char=='E' or char=='I' or char=='O' or char=='U':
    vow=vow+1
  else:
    cons=cons+1
print("count of vowels:",vow)
print("count of consonents:",cons)
# Out:
# Enter your string:kavya
# count of vowels: 2
# count of consonents: 3

# %%
a=input("enter the string:")
b=input("enter the string:")
if(sorted(a)==sorted(b)):
  print("These strings are anagram strings")
else:
  print("These strings are not anagram strings")
# Out:
# enter the string:listen
# enter the string:silents
# These strings are not anagram strings

# %%
a=input("Enter your string:")
space=""
for ch in a:
  if ch!=" ":
    space=space+ch
print("The string without space:",space)
# Out:
# Enter your string:python is too bad
# The string without space: pythonistoobad

# %%
a=input("Enter your string:")
space=""
for char in a:
  if char not in space:
    space=space+char
print("new string:",space)
# Out:
# Enter your string:kavya
# new string: kavy

# %%
n1=int(input("value of n1:"))
n2=int(input("value of n2:"))
a=[]
for _ in range(n1):
  a.append(int(input()))
b=[]
for i in range(n2):
  b.append(int(input()))
  combined_set=set(a+b)
  sorted_list=sorted(list(combined_set))
l=len(sorted_list)
if l%2==1:
  median=float(sorted_list[l/2])
else:
  mid1=sorted_list[(l//2)-1]
  mid2=sorted_list[l//2]
  median=(mid1+mid2)/2
  if median.is_integer():
    print(int(median))
  else:
    print(median)
